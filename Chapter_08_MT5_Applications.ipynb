# %%
from Chapter_08_MT5 import *
import warnings
warnings.filterwarnings("ignore")
import time
import numpy as np

def random():
    values = [True, False]
    buy = np.random.choice(values)
    sell = not buy
    
    return buy, sell

symbols_list = {
    "Nasdaq 100": ["NAS100", 0.1],
    "Russel 2000": ["US2000", 0.1],
    "Gold USD": ["XAUUSD", 0.01],
    "S&P 500": ["US500", 0.1],
    "Us dollar vs Canadian dollar": ["USDCAD", 0.01],
    "Euro vs USdollar": ["EURUSD", 0.01]}


current_account_info = mt5.account_info()
print("------------------------------------------------------------------")
print(f"Date: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Balance: {current_account_info.balance} USD,\t"
    f"Equity: {current_account_info.equity} USD, \t"
      f"Profit: {current_account_info.profit} USD")
print("------------------------------------------------------------------")



start = datetime.now().strftime("%H:%M:%S")#"23:59:59"

while True:

    # Launch the algorithm
    # Verfication for launch
    if datetime.now().weekday() not in (5,6):  
        is_time = datetime.now().strftime("%H:%M:%S") == start
    else:
        is_time = False

    if is_time:
        # Close all trades
        if mt5.positions_total() > 0:
            MT5.close_all_night()


        for asset in symbols_list.keys():
            # Initialize the inputs
            symbol = symbols_list[asset][0]
            lot = symbols_list[asset][1]

           
            buy, sell = random()

            # Run the algorithm
            MT5.run(symbol, buy, sell, lot)
# Out:
# ------------------------------------------------------------------
# Date: 2021-10-07 14:21:17
# Balance: 845.6 USD,	Equity: 844.55 USD, 	Profit: -1.05 USD
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Date:  2021-10-07 14:21:18
# SYMBOL: NAS100
# BUY: False 	  SHORT: True
# POSITION: None 	 ID: None
# OPEN SHORT TRADE: Request executed
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Date:  2021-10-07 14:21:18
# SYMBOL: US2000
# BUY: False 	  SHORT: True
# POSITION: None 	 ID: None
# OPEN SHORT TRADE: Request executed
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Date:  2021-10-07 14:21:18
# SYMBOL: XAUUSD
# BUY: False 	  SHORT: True
# POSITION: None 	 ID: None
# OPEN SHORT TRADE: Request executed
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Date:  2021-10-07 14:21:18
# SYMBOL: US500
# BUY: True 	  SHORT: False
# POSITION: None 	 ID: None
# OPEN LONG TRADE: Request executed
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Date:  2021-10-07 14:21:19
# SYMBOL: USDCAD
# BUY: False 	  SHORT: True
# POSITION: None 	 ID: None
# OPEN SHORT TRADE: Request executed
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Date:  2021-10-07 14:21:19
# SYMBOL: EURUSD
# BUY: False 	  SHORT: True
# POSITION: None 	 ID: None
# OPEN SHORT TRADE: Request executed
# ------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-dab64bba2c89> in <module>
#      38     # Verfication for launch
#      39     if datetime.now().weekday() not in (5,6):
# ---> 40         is_time = datetime.now().strftime("%H:%M:%S") == start
#      41     else:
#      42         is_time = False
#
# KeyboardInterrupt:

# %%
from Chapter_08_MT5 import *
import warnings
warnings.filterwarnings("ignore")
import time
import numpy as np
import ta

def rsi(symbol):
    overbuy = 70
    oversell = 30
    neutral = 50
    
    df = MT5.get_data(symbol, 3500).dropna()
    
    df["rsi"] = ta.momentum.RSIIndicator(df["close"], window=14).rsi()
    
    today = df["rsi"].iloc[-1]
    
    
    # Long buy signal
    long = (today > neutral) & (today < overbuy)
    
    # Short selling signal
    sell = (today < neutral) & (today > oversell)
    
    return long, sell
    
symbols_list = {
    "Nasdaq 100": ["NAS100", 0.1],
    "Russel 2000": ["US2000", 0.1],
    "Gold USD": ["XAUUSD", 0.01],
    "S&P 500": ["US500", 0.1],
    "Us dollar vs Canadian dollar": ["USDCAD", 0.01],
    "Euro vs USdollar": ["EURUSD", 0.01]}



current_account_info = mt5.account_info()
print("------------------------------------------------------------------")
print(f"Date: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Balance: {current_account_info.balance} USD,\t"
    f"Equity: {current_account_info.equity} USD, \t"
      f"Profit: {current_account_info.profit} USD")
print("------------------------------------------------------------------")



start = datetime.now().strftime("%H:%M:%S")#"23:59:59"
while True:

    # Launch the algorithm
    # Verfication for launch
    if datetime.now().weekday() not in (5,6):  
        is_time = datetime.now().strftime("%H:%M:%S") == start
    else:
        is_time = False

    if is_time:
        # Close all trades
        if mt5.positions_total() > 0:
            MT5.close_all_night()


        for asset in symbols_list.keys():
            # Initialize the inputs
            symbol = symbols_list[asset][0]
            lot = symbols_list[asset][1]

           
            buy, sell = rsi(symbol)

            # Run the algorithm
            MT5.run(symbol, buy, sell, lot)
# Out:
# ------------------------------------------------------------------
# Date: 2021-10-07 14:25:43
# Balance: 844.33 USD,	Equity: 844.41 USD, 	Profit: 0.08 USD
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Date:  2021-10-07 14:25:44
# SYMBOL: NAS100
# BUY: False 	  SHORT: True
# POSITION: None 	 ID: None
# OPEN SHORT TRADE: Request executed
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Date:  2021-10-07 14:25:44
# SYMBOL: US2000
# BUY: True 	  SHORT: False
# POSITION: None 	 ID: None
# OPEN LONG TRADE: Request executed
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Date:  2021-10-07 14:25:44
# SYMBOL: XAUUSD
# BUY: False 	  SHORT: True
# POSITION: None 	 ID: None
# OPEN SHORT TRADE: Request executed
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Date:  2021-10-07 14:25:45
# SYMBOL: US500
# BUY: False 	  SHORT: True
# POSITION: None 	 ID: None
# OPEN SHORT TRADE: Request executed
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Date:  2021-10-07 14:25:45
# SYMBOL: USDCAD
# BUY: False 	  SHORT: True
# POSITION: None 	 ID: None
# OPEN SHORT TRADE: Request executed
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Date:  2021-10-07 14:25:45
# SYMBOL: EURUSD
# BUY: False 	  SHORT: False
# POSITION: None 	 ID: None
# ------------------------------------------------------------------
